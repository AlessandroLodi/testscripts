# %% [markdown]
# ## Import Packages

# %%
import os;
import numpy as np;
# import matplotlib.pyplot as plt;
# import string;
# from imports.qtlab_data import *;
# from imports.dataclass import *;
# from imports.physics_models import *;
from helper_functions import *;
# Out:
# C:\Users\oums1095\AppData\Roaming\Python\Python37\site-packages\matplotlib\mpl-data
# cmex10
# DejaVu Sans Mono
# STIXGeneral
# STIXSizeThreeSym
# cmb10
# STIXNonUnicode
# STIXSizeThreeSym
# STIXSizeOneSym
# DejaVu Sans Mono
# STIXSizeFourSym
# STIXSizeTwoSym
# STIXGeneral
# cmmi10
# STIXSizeOneSym
# DejaVu Sans
# DejaVu Sans Display
# DejaVu Sans
# cmtt10
# STIXNonUnicode
# STIXSizeFourSym
# DejaVu Serif
# cmss10
# STIXSizeFiveSym
# STIXSizeTwoSym
# DejaVu Sans
# DejaVu Sans
# DejaVu Serif
# DejaVu Serif
# STIXGeneral
# STIXNonUnicode
# DejaVu Sans Mono
# STIXGeneral
# DejaVu Serif Display
# cmr10
# DejaVu Sans Mono
# DejaVu Serif
# STIXNonUnicode
# cmsy10
# News701 BT
# Microsoft Tai Le
# Mistral
# Euclid Fraktur
# Swis721 WGL4 BT
# Calisto MT
# Gill Sans MT
# Times New Roman
# Palace Script MT
# MS Reference Specialty
# Arial
# Imprint MT Shadow
# Malgun Gothic
# Humnst777 Lt BT
# Perpetua Titling MT
# Bodoni Bd BT
# Lucida Sans Typewriter
# Magneto
# Ravie
# Square721 Cn BT
# ...

# %% [markdown]
# ## Give a list of dirs and folders

# %%
from pathlib import Path
import glob
p = Path('G:/2021') # change backward w/ forward slashes
dir_list = [x for x in p.iterdir() if x.is_dir()]

# %%
for f in dir_list:
    grab_just_SD(f)
# Out:
# 094242_AG_LG05_3_IVsVg_a1.dat
# 094529_AG_LG05_3_IVsVg_a2.dat
# 094815_AG_LG05_3_IVsVg_a3.dat
# 095101_AG_LG05_3_IVsVg_a4.dat
# 095347_AG_LG05_3_IVsVg_a5.dat
# 095633_AG_LG05_3_IVsVg_a6.dat
# 095919_AG_LG05_3_IVsVg_a7.dat
# 100205_AG_LG05_3_IVsVg_a8.dat
# 100451_AG_LG05_3_IVsVg_a9.dat
# 100737_AG_LG05_3_IVsVg_a10.dat
# 101023_AG_LG05_3_IVsVg_a11.dat
# 101309_AG_LG05_3_IVsVg_a12.dat
# 101555_AG_LG05_3_IVsVg_a13.dat
# 101841_AG_LG05_3_IVsVg_a14.dat
# 102127_AG_LG05_3_IVsVg_a15.dat
# 102413_AG_LG05_3_IVsVg_a16.dat
# 102700_AG_LG05_3_IVsVg_a17.dat
# 102945_AG_LG05_3_IVsVg_a18.dat
# 103231_AG_LG05_3_IVsVg_a19.dat
# 103518_AG_LG05_3_IVsVg_b1.dat
# 103804_AG_LG05_3_IVsVg_b2.dat
# 104050_AG_LG05_3_IVsVg_b3.dat
# 104336_AG_LG05_3_IVsVg_b4.dat
# 104622_AG_LG05_3_IVsVg_b5.dat
# 104908_AG_LG05_3_IVsVg_b6.dat
# 105154_AG_LG05_3_IVsVg_b7.dat
# 105440_AG_LG05_3_IVsVg_b8.dat
# 105726_AG_LG05_3_IVsVg_b9.dat
# 110012_AG_LG05_3_IVsVg_b10.dat
# 110258_AG_LG05_3_IVsVg_b11.dat
# ...

# %%
for f in dir_list:
    print(type(f))
# Out:
# <class 'pathlib.WindowsPath'>
# <class 'pathlib.WindowsPath'>
# <class 'pathlib.WindowsPath'>
# <class 'pathlib.WindowsPath'>
# <class 'pathlib.WindowsPath'>
