# %%
from imports import qtlab_data
from imports import dataclass
import os

# %% [markdown]
# ## Find the Data

# %%
data_dir = r"C:\\Users\\oums1095\\Nexus365\\Simen Sopp - OxNanoSpin Team Folder\\Transport\\Ale01_r31\\5.Temperature_Dataset\copy_justSD_Aug"
fig_dir = r"C:\\Users\\oums1095\\projects\\gnr_set"
os.chdir(data_dir)
# find the data
# dataset = qtlab_data.QTLab_Dataset.find()

# %% [markdown]
# ## Load Stability Diagram Data

# %%
# load the data, in this case I load just one by indexing the dataset
data = dataset[0].load(qtlab_data.Stability_Diagram, axes=("Vg", "T", "Vsd", "Isd", "t"))
sd = data[0]
# Out:
# >>> Loading ./012748_Ale01_IVsVg_r31.dat
# Stability diagram measure at 238.49 K

# %%
sd['Vsd'].values.shape, sd['Isd'].values.shape
# Out:
# ((512, 512), (512, 512))

# %% [markdown]
# ## Data Pre-processing

# %%
T = sd['T'].values.mean() # sd is a Pandas df so retrieve the numpy object
print(f"Stability diagram measure at {round(T,2)} K")
sd["Vsd"] *= 1e-3 # the methods want to work in V and not mV
sd.resample(512, 512)
sd.correct_offset() # subtract a (quasi)-zero-bias gate trace
gatetrace = sd.zero_bias_gate_trace() # gatetrace is stil a Stability_Diagram Object

# %% [markdown]
# ## EDA Post Pre-processing

# %%
fig = dataclass.Figure()

# %%
fig.add_subplot(qtlab_data.Subplot_IVsVg(sd, title=f"sd_{T}_K", cmap='plasma'))
fig.add_subplot(qtlab_data.Subplot_GVg(gatetrace, title=f"zbgt_{T}_K", cmap='plasma'))

# %%
os.chdir(fig_dir)
fig.visualise(save_as='sd_analysis/test_figure_plasma')
# Out:
# C:\Users\oums1095\Dropbox (Personal)\My PC (OUMS-DOTTI)\Documents\ps_analysis_github\testscripts\imports\dataclass.py:506: MatplotlibDeprecationWarning:
# The get_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.get_clim instead.
#   np.max(np.abs(subplot["cbar"].get_clim())),

# %% [markdown]
# ## Manual Fit

# %%
sd.manual_fit_Vc()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-7cef811293d6> in <module>
# ----> 1 gatetrace.manual_fit_Vc()
#
# ~\Dropbox (Personal)\My PC (OUMS-DOTTI)\Documents\ps_analysis_github\testscripts\imports\qtlab_data.py in manual_fit_Vc(self, **kwargs)
#     989     def manual_fit_Vc(self, **kwargs):
#     990         fig = Figure()
# --> 991         fig.add_subplot(Subplot_FitVc(self, **kwargs))
#     992         fig.visualise()
#     993         return self.ps("Vc")["Vc"]
#
# ~\Dropbox (Personal)\My PC (OUMS-DOTTI)\Documents\ps_analysis_github\testscripts\imports\qtlab_data.py in __init__(self, *args, **kwargs)
#     236         if len(args) != 1:
#     237             return
# --> 238         super().__init__(args[0], **kwargs)
#     239
#     240
#
# ~\Dropbox (Personal)\My PC (OUMS-DOTTI)\Documents\ps_analysis_github\testscripts\imports\qtlab_data.py in __init__(self, *args, **kwargs)
#      98                     pass
#      99                 d["Gsd"] = d["Isd"].derive(
# --> 100                     x=d["Vsd"], method=kwargs.get("method", "savgol")
#     101                 )
#     102                 d.axes = ("Vg", "Vsd", "Gsd")
#
# ~\Dropbox (Personal)\My PC (OUMS-DOTTI)\Documents\ps_analysis_github\testscripts\imports\dataclass.py in __getitem__(self, item)
#     759         if type(item) is str:
#     760             dat = self.copy()
# --> 761             dat._data = {item: self._data[item]}
#     762             return dat
#     763         if type(item) is np.ndarray:
#
# KeyError: 'Vsd'
